# %%
import gym
import random
import numpy as np
import timeit
from IPython.display import clear_output
import sys
import yaml

# %%
from routing_003.envs import Routing

# %%
env = gym.make('routing-v2')
# Out:
# init hgthghghghg
# source =  6
# destination =  5
# curr_state =  53
# new_state 16
# new_state 48
# new_state 17
# new_state 49
# destination reached
# new_state 50
# new_state 19
# new_state 51
# new_state 20
# new_state 52
# new_state 21
# new_state 53
# new_state 22
# destination reached
# new_state 23
# new_state 55
# new_state 24
# new_state 56
# new_state 25
# new_state 57
# new_state 26
# new_state 58
# destination reached
# new_state 59
# new_state 28
# new_state 60
# new_state 29
# new_state 61
# new_state 30
# new_state 62
# new_state 31
# destination reached
# destination reached
# new_state 40
# new_state 1
# new_state 41
# new_state 2
# new_state 42
# new_state 3
# new_state 43
# new_state 4
# new_state 44
# new_state 5
# destination reached
# new_state 6
# new_state 46
# new_state 7
# new_state 47
# new_state 8
# new_state 32
# destination reached
# new_state 33
# new_state 10
# new_state 34
# new_state 11
# new_state 35
# new_state 12
# destination reached
# new_state 13
# new_state 37
# new_state 14
# new_state 38
# new_state 15
# new_state 39
# new_state 24
# new_state 56
# new_state 25
# new_state 57
# new_state 26
# new_state 58
# destination reached
# new_state 59
# new_state 28
# new_state 60
# new_state 29
# new_state 61
# new_state 30
# new_state 62
# new_state 31
# destination reached
# new_state 16
# new_state 48
# new_state 17
# new_state 49
# destination reached
# new_state 50
# new_state 19
# new_state 51
# new_state 20
# new_state 52
# new_state 21
# new_state 53
# new_state 22
# destination reached
# new_state 23
# new_state 55
# destination reached
# new_state 40
# new_state 1
# new_state 41
# new_state 2
# new_state 42
# new_state 3
# new_state 43
# new_state 4
# new_state 44
# new_state 5
# destination reached
# new_state 6
# new_state 46
# new_state 7
# new_state 47
# new_state 8
# new_state 32
# destination reached
# new_state 33
# new_state 10
# new_state 34
# new_state 11
# new_state 35
# new_state 12
# destination reached
# new_state 13
# new_state 37
# new_state 14
# new_state 38
# new_state 15
# new_state 39

# %%
#env.reset()
env.action_space
# Out:
# Discrete(8)

# %%
#env.step()
#env.observation_space
#env.reset()
#env.render()

# %%
action_space_size = env.action_space.n
state_space_size = env.observation_space.n
q_table = np.zeros((state_space_size,action_space_size))
#print(q_table)

# %%
num_episodes = 10000
max_steps_per_episode = 100

learning_rate = 0.1
discount_rate = 0.99

exploration_rate = 1
max_exploration_rate = 1
min_exploration_rate = 0.01
exploration_decay_rate = 0.001

# %%
rewards_all_episodes = []


#Q-Learning algorithm
for episode in range(num_episodes):
    state = env.reset()
    new_state = state
    reward = 0
    
    done = False
    rewards_current_episodes = 0
    
    for step in range(max_steps_per_episode):
        
           #exploration exploiatation trade-off
            exploration_rate_threshold = random.uniform(0,7)
            if exploration_rate_threshold > exploration_rate:
                #print("state for action : ", state)
                action = np.argmax(q_table[state,:])
             #print("max action = ", action)
            else:
                action = random.randrange(0,7)#choose any node from 0 to 7
                #print("random action", action )
            #new_state, reward, done, info = env.step(action)
        
        # Update Q-Table for Q(s,a)
        
            q_table[state,action] = q_table[state,action] * (1 - learning_rate) + \
 learning_rate * (reward + discount_rate*np.max(q_table[new_state,:]))
        
            state = new_state
            rewards_current_episodes += reward

            if done == True:
                break
            #exploration rate decay
            exploration_rate = min_exploration_rate + \
           (max_exploration_rate - min_exploration_rate) * \
            np.exp(-exploration_decay_rate*episode)
        
            rewards_all_episodes.append(rewards_current_episodes)
    
#print(np.array(rewards_all_episodes))
#calculate and print the avg reqard per thousand episodes
#rewards_per_thousand_episodes = np.split(np.array(rewards_all_episodes),num_episodes/1000)
count = 1000

#print("********Average reward per thousand episodes********\n")
#for r in rewards_per_thousand_episodes:
 #   print(count, ": ", str(sum(r/1000)))
 #   count += 1000
    
#Print updated Q table 
#print("\n\n-------Q-table-------\n")
#print(q_table)
# Out:
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  6
# ...
# reset curr_state =  44
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  3
# Destination =  0
# --------------------------------
# reset curr_state =  24
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  2
# Destination =  4
# --------------------------------
# reset curr_state =  20
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  2
# Destination =  3
# --------------------------------
# reset curr_state =  19
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  1
# Destination =  6
# --------------------------------
# reset curr_state =  14
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  0
# Destination =  1
# --------------------------------
# reset curr_state =  1
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  1
# Destination =  4
# --------------------------------
# reset curr_state =  12
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  5
# Destination =  0
# --------------------------------
# reset curr_state =  40
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  1
# Destination =  0
# --------------------------------
# reset curr_state =  8
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  3
# Destination =  5
# --------------------------------
# reset curr_state =  29
# ================================
# Source =  6
# Destination =  4
# --------------------------------
# reset curr_state =  52
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  6
# Destination =  3
# --------------------------------
# reset curr_state =  51
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  4
# Destination =  0
# --------------------------------
# reset curr_state =  32
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  6
# --------------------------------
# reset curr_state =  6
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  5
# Destination =  3
# --------------------------------
# reset curr_state =  43
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  2
# Destination =  5
# --------------------------------
# reset curr_state =  21
# ================================
# Source =  0
# Destination =  4
# --------------------------------
# reset curr_state =  4
# ================================
# Source =  4
# Destination =  2
# --------------------------------
# reset curr_state =  34
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  0
# Destination =  2
# --------------------------------
# reset curr_state =  2
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  0
# Destination =  3
# --------------------------------
# reset curr_state =  3
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  6
# Destination =  5
# --------------------------------
# reset curr_state =  53
# ================================
# Source =  5
# Destination =  1
# --------------------------------
# reset curr_state =  41
# ================================
# Source =  0
# Destination =  5
# --------------------------------
# reset curr_state =  5
# ================================
# Source =  1
# Destination =  3
# --------------------------------
# reset curr_state =  11
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  4
# Destination =  5
# --------------------------------
# reset curr_state =  37
# ================================
# Source =  3
# Destination =  4
# --------------------------------
# reset curr_state =  28
# ================================
# Source =  2
# Destination =  6
# --------------------------------
# reset curr_state =  22
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  2
# Destination =  0
# --------------------------------
# reset curr_state =  16
# ================================
# Source =  3
# Destination =  6
# --------------------------------
# reset curr_state =  30
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  6
# Destination =  0
# --------------------------------
# reset curr_state =  48
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  3
# Destination =  2
# --------------------------------
# reset curr_state =  26
# ================================
# Source =  4
# Destination =  6
# --------------------------------
# reset curr_state =  38
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  1
# Destination =  2
# --------------------------------
# reset curr_state =  10
# ================================
# Source =  2
# Destination =  1
# --------------------------------
# reset curr_state =  17
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  6
# Destination =  1
# --------------------------------
# reset curr_state =  49
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
# Source =  5
# Destination =  2
# --------------------------------
# reset curr_state =  42
# ================================
# Source =  6
# Destination =  2
# --------------------------------
# reset curr_state =  50
# ================================
# Source =  1
# Destination =  5
# --------------------------------
# reset curr_state =  13
# ================================
# Source =  5
# Destination =  6
# --------------------------------
# reset curr_state =  46
# ================================
# Source =  3
# Destination =  1
# --------------------------------
# reset curr_state =  25
# ================================
# Source =  4
# Destination =  1
# --------------------------------
# reset curr_state =  33
# ================================
# Source =  4
# Destination =  3
# --------------------------------
# reset curr_state =  35
# ================================
# Source =  5
# Destination =  4
# --------------------------------
# reset curr_state =  44
# ================================
