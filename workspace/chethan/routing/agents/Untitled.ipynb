# %%
import gym
import random
import numpy as np
import time

# %%
from routing_002.envs import Routing

# %%
env = gym.make('routing-v1')
# Out:
# init 1

# %%
env.reset()
# Out:
# called function reset
